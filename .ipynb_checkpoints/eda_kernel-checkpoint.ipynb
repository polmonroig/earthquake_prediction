# %%
DATA_DIR = "data/"
TRAIN_DATA_DIR = paste(DATA_DIR, "trian/", sep="")
features <- c("acoustic_data", "time_to_failure")

# %%
n_samples = 2
data <- read.csv(paste(DATA_DIR, "train.csv", sep=""), 
                 header=TRUE,
                 nrows=SAMPLE_SIZE * n_samples)

# %%
qqnorm(data$acoustic_data)
hist(data$acoustic_data)
abline(a=0, b=1, col="grey")
# Out:
# Plot with title “Normal Q-Q Plot”
# Plot with title “Histogram of data$acoustic_data”
